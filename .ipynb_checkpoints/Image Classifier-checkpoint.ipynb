# %% [markdown]
# Based on: https://www.youtube.com/watch?v=jztwpsIzEGc

# %% [markdown]
# ## Building Data Pipeline

# %% [markdown]
# #### Install Dependencies

# %%
#GPU compatibility only for tensorflow versions lower than 2.11
# !pip install tensorflow==2.10 opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.10 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (2.10.0)
# Requirement already satisfied: opencv-python in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (4.7.0.72)
# Requirement already satisfied: matplotlib in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (3.7.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (16.0.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (3.8.0)
# Requirement already satisfied: packaging in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (23.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.16.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (2.10.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.23.5)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (0.31.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (3.19.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (4.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (1.53.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (2.10.0)
# Requirement already satisfied: setuptools in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorflow==2.10) (57.4.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (2.17.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tushar\documents\ml courses\projenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.2.2)

# %%
import tensorflow as tf
import os

# %%
#Set GPU Memory Consumption Growth (Limits tensorflow from using all the vRAM on GPU)
#By default, uses all potential vRAM, helps prevent OutOfMemory error
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# #### Image Data

# %%
import cv2 #Computer vision module
import imghdr #Checks image file extensions
from matplotlib import pyplot as plt

# %%
data_dir = 'data'
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
os.listdir(data_dir)
# Out:
# ['crab', 'fish', 'squid']

# %% [markdown]
# Note for Additional cleanup: Manually delete any image files in data folders that are <10kb (too small for good data) or svg files

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            image = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print("Issue with image {}".format(image_path))
#             os.remove(image_path)

# %% [markdown]
# #### Load Data

# %%
#Tensorflow dataset API: Allows to build a data pipeline instead of loading data to memory
#tf.data.Dataset

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#Keras: API that provides a python interface for neural networks
#Data pipeline helper function via keras
#Does preprocessing as well, can be altered
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 286 files belonging to 3 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator = data.as_numpy_iterator()

# %%
#Gets next batch from numpy iterator, helpful for big data
batch = data_iterator.next()

# %%
len(batch) #2 = Images and labels
# Out:
# 2

# %%
batch[1] #Labels
# Out:
# array([1, 1, 0, 1, 0, 0, 0, 2, 1, 0, 0, 2, 0, 1, 1, 2, 1, 0, 2, 1, 2, 2,
#        1, 1, 0, 1, 1, 0, 0, 1, 2, 0])

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
#Visualizes some images, sets title as their label
#0 = crab
#1 = fish
#2 = squid
fig, ax = plt.subplots(ncols=4, figsize=(20, 20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### Scale Data

# %%
#Want channel values (RGB) to be as small as possible, to help optimize faster
#Divide by 255 (max possible RGB value)
scaled = batch[0]/255
scaled.max()
#Need a way to scale data while data is being loaded through data pipeline
# Out:
# 1.0

# %%
#Maps function to dsatapoints in pipeline so data x value (which is the image values) get automatically scaled down
#y val = labels
#Allows a function to be conducted on multiple values throughout the dataset
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[8.20772052e-02, 3.77703726e-01, 4.29541975e-01],
#           [9.43627488e-03, 3.59076291e-01, 4.12385106e-01],
#           [1.26225492e-02, 3.59926462e-01, 4.23912376e-01],
#           ...,
#           [1.25206798e-01, 1.29442406e-03, 5.40594339e-01],
#           [1.18382350e-01, 4.16666688e-03, 5.41666687e-01],
#           [7.82245696e-02, 1.26378681e-03, 5.26263773e-01]],
#
#          [[8.97135437e-02, 3.86787683e-01, 4.51508880e-01],
#           [3.59681360e-02, 3.84696692e-01, 4.57123160e-01],
#           [2.30851714e-02, 3.75367641e-01, 4.46813732e-01],
#           ...,
#           [1.38970584e-01, 0.00000000e+00, 5.38396120e-01],
#           [1.26815259e-01, 2.38204654e-03, 5.40027559e-01],
#           [7.20588267e-02, 8.42524518e-04, 5.16421556e-01]],
#
#          [[1.46882653e-01, 4.08455878e-01, 4.90196079e-01],
#           [7.99326003e-02, 3.87737453e-01, 4.70703125e-01],
#
#          [[5.02624273e-01, 2.71527469e-01, 1.45945355e-01],
#           [4.28940237e-01, 2.10159600e-01, 8.27921554e-02],
#           [3.60225171e-01, 1.54586494e-01, 5.22209629e-02],
#           ...,
#           [9.28456247e-01, 7.95435071e-01, 6.64427996e-01],
#           [7.29402184e-01, 5.84965467e-01, 4.70083207e-01],
#           [5.42102754e-01, 3.89345407e-01, 2.75619924e-01]],
#
#          [[4.70166504e-01, 2.39069685e-01, 1.10914521e-01],
#           [4.47940856e-01, 2.29160205e-01, 1.02225751e-01],
#           [3.11662018e-01, 1.05657123e-01, 8.72802734e-03],
#           ...,
#           [9.80990529e-01, 8.51443052e-01, 7.24574208e-01],
#           [8.23819995e-01, 6.79643929e-01, 5.67540765e-01],
#           [5.46418548e-01, 3.96234244e-01, 2.85143554e-01]],
#
#          ...,
#
#          [[2.04905793e-01, 1.21358238e-01, 3.61256301e-02],
#           [4.68224853e-01, 3.90437573e-01, 2.94909894e-01],
#           [6.46781623e-01, 5.78885913e-01, 4.81523097e-01],
#           ...,
#           [2.77941167e-01, 2.26960778e-01, 7.81544372e-02],
#           [2.42800251e-01, 1.88174024e-01, 3.29956040e-02],
#           [2.53369868e-01, 1.98467895e-01, 4.28306423e-02]],
#
#          [[2.17834234e-01, 1.35646448e-01, 5.30910119e-02],
#           [3.51957202e-01, 2.76982576e-01, 1.86319515e-01],
#           [4.31093454e-01, 3.62343460e-01, 2.74203658e-01],
#           ...,
#           [2.47210577e-01, 1.96047083e-01, 6.43054470e-02],
#           [2.11703435e-01, 1.55624568e-01, 2.15760469e-02],
#           [2.19460636e-01, 1.62996173e-01, 2.57838834e-02]],
#
#          [[2.77879894e-01, 1.95802703e-01, 1.13357842e-01],
#           [2.47181371e-01, 1.76593140e-01, 9.11458358e-02],
#           [1.46936268e-01, 7.81862736e-02, 4.59558825e-04],
#           ...,
#           [2.14736521e-01, 1.63296565e-01, 3.91850509e-02],
#           [1.78676471e-01, 1.20404415e-01, 2.20588245e-03],
#           [1.84129909e-01, 1.25306368e-01, 0.00000000e+00]]]],
#        dtype=float32),
#  array([1, 2, 2, 0, 1, 1, 2, 0, 2, 0, 1, 1, 0, 1, 2, 2, 1, 1, 0, 0, 2, 1,
#         1, 1, 0, 0, 0, 1, 0, 2, 1, 0]))

# %% [markdown]
# #### Split Data

# %%
len(data)
# Out:
# 9

# %%
#70% training data, 20% validating data, 10% testing data
train_size = int(len(data) * 0.7)
val_size = int(len(data) * 0.2) + 1
test_size = int(len(data) * 0.1) + 1 #Only used for evaluation

# %%
val_size + test_size + train_size
# Out:
# 9

# %%
train = data.take(train_size) #Takes only number of batches from data specified by train_size
val = data.skip(train_size).take(val_size) #Skips first part of data already assigned to training data and takes val_size amount after
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ## Building Deep Neural Network

# %% [markdown]
# #### Build Deep Learning Model

# %%
from tensorflow.keras.models import Sequential #Good for 1 data input and 1 output
#use Functional for multiple inputs/outputs/connections
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
#16 filters, filter is 3x3 pixels, stride = 1 (moves 1 pixel at a time)
#Activations: Take in output data and modify the outputs via a function to fit certain parameters
#relu activation function takes output and converts <0 outputs to 0, and preserves positive values
model.add(Conv2D(16, (3, 3), 1, activation='relu', input_shape=(256, 256, 3))) #First layer is input layer
model.add(MaxPooling2D()) #Takes and returns max values after relu activation, condenses

#32 filters
model.add(Conv2D(32, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D())

#16 filters
model.add(Conv2D(16, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten()) #Condenses to single dimension

#Fully connected layers
model.add(Dense(256, activation='relu'))
model.add(Dense(3, activation='sigmoid')) #Single output, 3 = number of possible outputs (0, 1, 2)

# %%
#adam = optimizer
#SparseCategoricalCrossentropy used b/c there are 2+ possible y_values, and they are mutually exclusive (only 1 label per input)
model.compile('adam', loss=tf.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 3,697,139
# Trainable params: 3,697,139
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
#Epoch = A run over our entire training set, the more epochs = better understanding
#TOO many epochs could mean too much accuracy for only training data, not very usable
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 6/6 [==============================] - 7s 435ms/step - loss: 2.2622 - accuracy: 0.3073 - val_loss: 1.2653 - val_accuracy: 0.2969
# Epoch 2/20
# 6/6 [==============================] - 4s 409ms/step - loss: 1.1321 - accuracy: 0.3542 - val_loss: 1.0876 - val_accuracy: 0.6094
# Epoch 3/20
# 6/6 [==============================] - 4s 452ms/step - loss: 1.0677 - accuracy: 0.5104 - val_loss: 1.0079 - val_accuracy: 0.3906
# Epoch 4/20
# 6/6 [==============================] - 4s 446ms/step - loss: 0.9848 - accuracy: 0.4062 - val_loss: 0.9543 - val_accuracy: 0.5469
# Epoch 5/20
# 6/6 [==============================] - 4s 422ms/step - loss: 0.8769 - accuracy: 0.5938 - val_loss: 0.7928 - val_accuracy: 0.6406
# Epoch 6/20
# 6/6 [==============================] - 4s 445ms/step - loss: 0.8144 - accuracy: 0.6510 - val_loss: 0.7453 - val_accuracy: 0.7031
# Epoch 7/20
# 6/6 [==============================] - 4s 420ms/step - loss: 0.7385 - accuracy: 0.6771 - val_loss: 0.5423 - val_accuracy: 0.7656
# Epoch 8/20
# 6/6 [==============================] - 4s 452ms/step - loss: 0.5927 - accuracy: 0.7760 - val_loss: 0.7582 - val_accuracy: 0.6250
# Epoch 9/20
# 6/6 [==============================] - 4s 439ms/step - loss: 0.7743 - accuracy: 0.6875 - val_loss: 0.5112 - val_accuracy: 0.7500
# Epoch 10/20
# 6/6 [==============================] - 4s 451ms/step - loss: 0.5379 - accuracy: 0.7760 - val_loss: 0.4407 - val_accuracy: 0.8906
# Epoch 11/20
# 6/6 [==============================] - 4s 429ms/step - loss: 0.4852 - accuracy: 0.8125 - val_loss: 0.3849 - val_accuracy: 0.8750
# Epoch 12/20
# 6/6 [==============================] - 4s 463ms/step - loss: 0.4085 - accuracy: 0.8646 - val_loss: 0.3846 - val_accuracy: 0.8594
# Epoch 13/20
# 6/6 [==============================] - 4s 436ms/step - loss: 0.3070 - accuracy: 0.9062 - val_loss: 0.4216 - val_accuracy: 0.8281
# Epoch 14/20
# 6/6 [==============================] - 4s 457ms/step - loss: 0.3005 - accuracy: 0.8958 - val_loss: 0.1964 - val_accuracy: 0.9375
# Epoch 15/20
# 6/6 [==============================] - 4s 441ms/step - loss: 0.2613 - accuracy: 0.9010 - val_loss: 0.2250 - val_accuracy: 0.9375
# Epoch 16/20
# 6/6 [==============================] - 4s 448ms/step - loss: 0.2243 - accuracy: 0.9271 - val_loss: 0.1106 - val_accuracy: 0.9688
# Epoch 17/20
# 6/6 [==============================] - 4s 442ms/step - loss: 0.1433 - accuracy: 0.9688 - val_loss: 0.1470 - val_accuracy: 0.9688
# Epoch 18/20
# 6/6 [==============================] - 4s 441ms/step - loss: 0.1236 - accuracy: 0.9792 - val_loss: 0.0696 - val_accuracy: 0.9844
# Epoch 19/20
# 6/6 [==============================] - 4s 443ms/step - loss: 0.0872 - accuracy: 0.9740 - val_loss: 0.1373 - val_accuracy: 0.9688
# Epoch 20/20
# 6/6 [==============================] - 4s 438ms/step - loss: 0.0705 - accuracy: 0.9948 - val_loss: 0.0549 - val_accuracy: 1.0000

# %%
hist.history
# Out:
# {'loss': [2.2621538639068604,
#   1.1321073770523071,
#   1.0676931142807007,
#   0.9847525954246521,
#   0.8769027590751648,
#   0.8144032955169678,
#   0.7384995818138123,
#   0.5926889777183533,
#   0.7742519378662109,
#   0.5379405617713928,
#   0.48523175716400146,
#   0.4084714353084564,
#   0.3070123493671417,
#   0.3005276918411255,
#   0.26131394505500793,
#   0.22429315745830536,
#   0.1432671695947647,
#   0.12360033392906189,
#   0.08719658851623535,
#   0.07048354297876358],
#  'accuracy': [0.3072916567325592,
#   0.3541666567325592,
#   0.5104166865348816,
#   0.40625,
#   0.59375,
#   0.6510416865348816,
#   0.6770833134651184,
#   0.7760416865348816,
#   0.6875,
#   0.7760416865348816,
#   0.8125,
#   0.8645833134651184,
#   0.90625,
#   0.8958333134651184,
#   0.9010416865348816,
#   0.9270833134651184,
#   0.96875,
#   0.9791666865348816,
#   0.9739583134651184,
#   0.9947916865348816],
#  'val_loss': [1.2653496265411377,
#   1.087554693222046,
#   1.0078681707382202,
#   0.9542891979217529,
#   0.7928129434585571,
#   0.7453467845916748,
#   0.5423200130462646,
#   0.7581720948219299,
#   0.5111804008483887,
#   0.4407457113265991,
#   0.38485923409461975,
#   0.38462671637535095,
#   0.4215771555900574,
#   0.19644367694854736,
#   0.22498247027397156,
#   0.11056597530841827,
#   0.14695152640342712,
#   0.06956681609153748,
#   0.1372651308774948,
#   0.05494377762079239],
#  'val_accuracy': [0.296875,
#   0.609375,
#   0.390625,
#   0.546875,
#   0.640625,
#   0.703125,
#   0.765625,
#   0.625,
#   0.75,
#   0.890625,
#   0.875,
#   0.859375,
#   0.828125,
#   0.9375,
#   0.9375,
#   0.96875,
#   0.96875,
#   0.984375,
#   0.96875,
#   1.0]}

# %% [markdown]
# #### Plot Performance

# %%
#If loss is decreasing but val_loss starts to increase, that is a sign of possible overfitting
#No change in loss or val_loss means training data should be looked at, or a more sophisticated nn, shows inability to learn 
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle("Loss", fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
#Accuracy Plotted
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle("Accuracy", fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# #### Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, SparseCategoricalAccuracy

# %%
pre = Precision()
recall = Recall()
acc = SparseCategoricalAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    print(y.shape)
    print(yhat.shape)
#     pre.update_state(y, yhat)
#     recall.update_state(y, yhat)
#     accuracy.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# (30,)
# (30, 3)
